# %%
from IPython.display import Image

# %% [markdown]
# # Community Detection by Modularity in Migration Network

# %% [markdown]
# ## network: UN Migrations
#
# - [source: netzschleuder](https://networks.skewed.de/net/un_migrations)
# - nodes: "Countries"
# - edges: directed Migrationflow
#     - weighted by amount of people migrating

# %% [markdown]
# <span style="color:red">maybe: node_table - edge_table - 2d-plot</span>

# %% [markdown]
# ## concept: Community detection and Modularity
#
# - explain Modularity and its role in Community detection
# - visualize an modularity based algorithm
#
#
#
# - algorithm used: [nx.greedy_modularity_communities()](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.community.modularity_max.greedy_modularity_communities.html)
# - algorithm based on this paper: [Moore, Clauset, Newman: "Finding community structure in very large networks"](https://arxiv.org/pdf/cond-mat/0408187.pdf)

# %%
Image(filename='modularity_fromLecture.png')

# %% [markdown]
# ## presentation preview:

# %% [markdown]
# ### (1) Modularity
#
# - use a simple toy graph and show modularity (like in lecture)

# %% [markdown]
# ### (2) Greedy Algorithm
#
# - explain algorithm:
# "Greedy modularity maximization begins with each node in its own community and joins the pair of communities that most increases modularity until no such pair exists or until a number of communities is reached." [(source)](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.community.modularity_max.greedy_modularity_communities.html)
# - show steps in the toy network

# %% [markdown]
# ### (3) Migration Network
#
# - show network
# - show iterations of the algorithm

# %% [markdown]
# ### (4) Results
#
# - colour the communities and interpret the findings

# %% [markdown]
# <span style="color:red">maybe: list of communities</span>

# %% [markdown]
# # Persistent Homology in Science Collaboration

# %% [markdown]
# ## network: Science Collaboration Network
#
# - [source: Mark Newman](http://www-personal.umich.edu/~mejn/netdata/)
# - nodes: scientists
# - edges: undirected paper-collaborations
#     - weighted by $$\sum_{\text{papers}} \frac{1}{\text{ # authors of paper} - 1}$$

# %%
Image(filename='collabNetworkPreview_fromPaper.png')

#screenshots taken from https://snap.stanford.edu/social2012/papers/carstens-horadam.pdf

# %% [markdown]
# ## concept: Persistent Homology
#
# - explain Persistent Homology
#     - betti numbers
# - motivate a different approach to analysing network inherent (topological) structure
#
#
# - based on paper: [Carstens, Horadam: "Persistent Homology of Collaboration Networks
# "](https://snap.stanford.edu/social2012/papers/carstens-horadam.pdf)

# %%
Image(filename='triangleBettiNumbers_fromPaper.png')

# screenshots taken from https://snap.stanford.edu/social2012/papers/carstens-horadam.pdf

# %% [markdown]
# <span style="color:red"> Maybe Screennshot from Brain </span> (hab ich leider nicht gefunden...)

# %% [markdown]
# ## presentation preview:

# %% [markdown]
# ### (1) Persistent Homology
#
# - explain concepts on toy network
# - show filtration

# %% [markdown]
# ### (2) Collaboration Network
#
# - show network
# - show statistics and iterations of persistent homology

# %% [markdown]
# ### (3) results
#
# - discuss findings
# - motivations for further research in the concept
